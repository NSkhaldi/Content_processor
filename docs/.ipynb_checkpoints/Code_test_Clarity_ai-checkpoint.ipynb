# %% [markdown]
# # Code test Junior Data Operations Engineer  Clarity.ai  (Notebook)

# %%
import numpy as np
import random
import time
import glob
import os
import sys
import unittest
import collections
from collections import Counter

# %%
#%%timeit

#every list comprehension can be rewritten in for loop, but every for loop can’t be rewritten in the form of list comprehension.
def connected_hostnames(logpath, init_datetime, end_datetime, Hostname):
    connected_hosts=[]
    
    input_log=open(logpath)
    for line in input_log:
        #Check if within the interval
        if (init_datetime<= int(line.split()[0]) <= end_datetime):
            #check if the host initialized the connection and append the receiver if true.
            if(line.split()[1]==Hostname):
                connected_hosts.append(line.split()[2])
            #check if the host received the connection and append the initializer if true.
            elif (line.split()[2]==Hostname):
                connected_hosts.append(line.split()[1])
        #Exit early: finish the process if the interval is exceeded         
        elif ((int(line.split()[0]) > end_datetime )):
                break
    input_log.close()
    return collections.Counter(connected_hosts)
            
'''
def connected_hostnames_one_liner(filepath, init_datetime, end_datetime, Hostname):
    s=[line.split()[2] if (init_datetime <= int(line.split()[0]) <= end_datetime and line.split()[1]==Hostname) else line.split()[1] if (init_datetime<= int(line.split()[0]) <= end_datetime and line.split()[2]==Hostname) else None for line in reversed(list(open(filepath)))]
    return list(filter(None, s))
'''

# %%
# %%timeit
connected_hostnames("data/input-file.txt",1565647205599,1565679364288, 'Jadon')
# Out:
# 4.02 ms ± 44.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
connected_hostnames_one_liner("data/input-file.txt",1565647205599,1565679364288, 'Jadon')
# Out:
# 13.5 ms ± 1.07 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
def connected_to(logpath, init_datetime, end_datetime, Hostname):
    hostnames=[]
    input_log=open(logpath)
    for line in reversed(list(input_log)):
        #print(''.join(['parsed line: ',line]))

        if (int(line.split()[0]) >= init_datetime and  int(line.split()[0])<= end_datetime and line.split()[2]==Hostname):
            #print(''.join(['----> considered line: ',line]))
            hostnames.append(line.split()[1])
            
        if(int(line.split()[0]) < init_datetime ):
            break
            
    #print('------------------ \n\n')
    input_log.close()
    return collections.Counter(hostnames)

# %%
def received_from(logpath, init_datetime, end_datetime, Hostname):
    hostnames=[]
    input_log=open(logpath)
    for line in reversed(list(input_log)):
        #print(''.join(['parsed line: ',line]))


        if (int(line.split()[0]) >= init_datetime and  int(line.split()[0])<= end_datetime and line.split()[1]==Hostname):
            #print(''.join(['----> considered line: ',line]))
            hostnames.append(line.split()[2])
            
        if(int(line.split()[0]) < init_datetime ):
            break
    #print('------------------ \n\n') 
    input_log.close()
    return collections.Counter(hostnames)

# %%
def generated_conn(logpath, init_datetime, end_datetime):
    hostnames=[]
    input_log=open(logpath)
    for line in reversed(list(input_log)):
        #print(''.join(['parsed line: ',line]))
        if (int(line.split()[0]) >= init_datetime and  int(line.split()[0])<= end_datetime ):
            #print(''.join(['----> considered line: ',line]))
            hostnames.append(line.split()[1])
        
        if(int(line.split()[0]) < init_datetime ):
            break
    
    #print('------------------ \n\n')
    input_log.close()
    return collections.Counter(hostnames)

# %%
'''
strings in Python are immutable, and the “+” operation involves creating a new string and copying the old content 
at each step. A more efficient approach would be to use the array module to modify the individual characters and 
then use the join() function to re-create your final string.
'''

def process_log_files(Hostname, past_time, log_ofo_time):

    
    #can achieve the same effect slightly faster by using while 1. This is a single jump operation, as it is a numerical comparison.
    while 1: 
        connected_hosts, received_hosts, active_hosts=Counter(),Counter(),Counter() 


        
        init_datetime=int((time.time()-past_time)*1000)
        end_datetime=int(time.time()*1000)
        past= time.time() - 5 # 5 seconds
        
        
        past_files=sorted( [ filename for filename in glob.glob("output/*.txt") if os.path.getmtime(filename)>=init_datetime/1000-log_ofo_time ] , key=os.path.getmtime)[::-1]
        
 
        for filename in past_files:
            connected_hosts+=connected_to(filename,init_datetime,end_datetime,Hostname)
            received_hosts+=received_from(filename,init_datetime,end_datetime,Hostname)
            active_hosts+=most_generated_conn(filename,init_datetime,end_datetime)
        
        '''
        ## Data transformation for display : 
            #converting 2d list into 1d , and consider multiple occurences by applying collection 
        connected_hosts=collections.Counter(sum(connected_hosts,[]))
        received_hosts=collections.Counter(sum(received_hosts,[]))
            #convert to collection to include other hosts if they have similar occurences as the first one.
        active_hosts= collections.Counter(sum(active_hosts,[]))
        '''
        active_hosts=[h for h in active_hosts.most_common() if h[1]==active_hosts.most_common(1)[0][1]]
            
        
        print(" ".join(['Hosts that connected to ', Hostname ,'in the last', str(past_time),'s are: ',str(connected_hosts),'\n']))
        print(" ".join(['Hosts that received connection from', Hostname ,'in the last', str(past_time),'s are: ',str(received_hosts),'\n']))
        print(" ".join(['the hostname that generated most connections in the last', str(past_time),'s is: ',  str(active_hosts),'\n']))
        
        print('--------------------------------\n\n')
        
        print(''.join(['It is :  ', time.strftime('%X %x'),'.  the next output is in ', str(past_time), ' s. \n']))
        time.sleep(past_time)

# %%
process_log_files('Hannibal', 5000 , 0 )
# Out:
# Hosts that connected to  Hannibal in the last 5000 s are:  Counter({'Hannibal': 7, 'Steeve': 6, 'Hanny': 6})
#
# Hosts that received connection from Hannibal in the last 5000 s are:  Counter({'Steeve': 10, 'Hanny': 9, 'Hannibal': 7})
#
# the hostname that generated most connections in the last 5000 s is:  [('Hannibal', 26)]
#
# --------------------------------
#
#
# It is :  23:36:13 12/13/20.  the next output is in 5000 s.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-911-4df0324143a0> in <module>
# ----> 1 process_log_files('Hannibal', 5000 , 0 )
#
# <ipython-input-889-b62a41481b28> in process_log_files(Hostname, past_time, log_ofo_time)
#      45
#      46         print(''.join(['It is :  ', time.strftime('%X %x'),'.  the next output is in ', str(past_time), ' s. \n']))
# ---> 47         time.sleep(past_time)
#      48
#      49
#
# KeyboardInterrupt:

# %%
class NamesTestCase(unittest.TestCase):
        
# Test connected_hostnames() on short and long files
    def test_connected_hostnames_sf(self):
        result = connected_hostnames("data/input_test_case_1.txt",1607880434801,1607880438820, 'Steeve')
        self.assertEqual(result, {'Hanny': 1, 'Hannibal': 2})
        
    def test_connected_hostnames_lf(self):
        result = connected_hostnames("data/input-file.txt",1565647204351,1565733598341, 'Dristen')
        self.assertEqual(result, {'Aadison': 1, 'Wilkens': 1, 'Kahlina': 1, 'Alei': 1, 'Zhanasia': 1, 'Jamor': 1, 'Joy': 1})


# Test connected_to() on short and long files
    def test_connect_to_sf(self):
        result = connected_to("data/input_test_case_1.txt",1607880434801,1607880438820, 'Steeve')
        self.assertEqual(result, {'Hannibal': 1})

    def test_connect_to_lf(self):
        result = connected_to("data/input-file.txt",1565647204351,1565733598341, 'Jadon')
        self.assertEqual(result, {'Ahmya': 1, 'Kayleann': 1, 'Shainah': 1, 'Aniyah': 1, 'Eveleigh': 1, 'Caris': 1, 'Rahniya': 1, 'Remiel': 1})


# Test received_from() on short and long files   
    def test_received_from_sf(self):
        result = received_from("data/input_test_case_1.txt",1607880434801,1607880438820, 'Steeve')
        self.assertEqual(result, {'Hannibal': 1, 'Hanny': 1})

    def test_received_from_lf(self):
        result = received_from("data/input-file.txt",1565647204351,1565733598341, 'Dristen')
        self.assertEqual(result, {'Joy': 1, 'Jamor': 1, 'Zhanasia': 1, 'Alei': 1, 'Kahlina': 1, 'Wilkens': 1, 'Aadison': 1})

# Test generated_conn
    def test_generated_conn(self):
        result = generated_conn("data/input_test_case_1.txt",1607880434801,1607880438820)
        self.assertEqual(result, {'Hannibal': 3, 'Steeve': 2, 'Hanny': 1})

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# 1607704341813 anass kuduro
#
# 1607704342813 kuduro kuduro
#
# 1607704343814 kuduro samatchi
#
# 1607704344818 kuduro anass
#
# 1607704345818 anass samatchi
#
# 1607704346823 anass samatchi
#
# 1607704347826 anass anass
#
# 1607704348830 samatchi samatchi
#
# 1607704349832 samatchi anass
#
# 1607704350836 anass kuduro
#
# 1607704351842 kuduro anass
#
# 1607704352844 kuduro anass
#
# 1607704353846 kuduro anass
#
# 1607704354847 kuduro anass
#
# 1607704355847 samatchi anass
#
# 1607704356850 kuduro kuduro
#
# 1607704357851 anass samatchi
#
# 1607704358856 anass samatchi
#
# 1607704359860 samatchi samatchi
#
# 1607704360861 samatchi anass
#
# 1607704361864 samatchi samatchi
#
# 1607704362867 kuduro samatchi
#
# 1607704363870 kuduro samatchi
#
# 1607704364875 kuduro anass
#
# 1607704365879 samatchi anass
#
# 1607704366881 kuduro anass
#
# 1607704367881 anass samatchi
#
# 1607704368886 samatchi anass
#
# 1607704369889 samatchi samatchi
#
# 1607704370893 samatchi kuduro
#
# 1607704371894 anass kuduro
#
# 1607704372898 kuduro samatchi
#
# 1607704373898 samatchi kuduro
#
# 1607704374898 kuduro samatchi
#
# 1607704375904 kuduro samatchi
#
# 1607704376906 anass anass
#
# 1607704377907 samatchi anass
#
# 1607704378907 anass anass
#
# 1607704379907 kuduro anass
#
# 1607704380908 anass samatchi
#
# 1607704381911 anass samatchi
#
# 1607704382913 samatchi samatchi
#
# 1607704383914 samatchi anass
#
# 1607704384915 anass anass
#
# 1607704385917 kuduro samatchi
#
# 1607704386921 samatchi anass
#
# 1607704387922 anass samatchi
#
# 1607704388922 samatchi kuduro
#
# 1607704389927 samatchi samatchi
#
# 1607704390928 kuduro samatchi
#
# 1607704391933 kuduro anass
#
# 1607704392937 samatchi kuduro
#
# 1607704393940 samatchi samatchi
#
# 1607704394945 kuduro kuduro
#
# 1607704395948 kuduro kuduro
#
# 1607704396953 samatchi kuduro
#
# 1607704397957 anass kuduro
#
# 1607704398962 anass anass
#
# 1607704399966 anass samatchi
#
# 1607704400967 samatchi kuduro
#
# 1607704401970 anass kuduro
#
# 1607704402974 anass kuduro
#
# 1607704403978 anass samatchi
#
# 1607704404983 kuduro samatchi
#
# 1607704405987 kuduro kuduro
#
# 1607704406990 samatchi anass
#
# 1607704407994 kuduro kuduro
#
# 1607704408997 kuduro samatchi
#
# 1607704410000 kuduro anass
#
# 1607704411003 samatchi samatchi
#
# 1607704412006 samatchi anass
#
# 1607704413011 anass samatchi
#
# 1607704414014 samatchi kuduro
#
# 1607704415018 kuduro samatchi
#
# 1607704416018 anass kuduro
#
# 1607704417023 samatchi samatchi
#
# 1607704418024 anass anass
#
# 1607704419025 samatchi kuduro
#
# 1607704420030 anass anass
#
# 1607704421031 kuduro samatchi
#
# 1607704422035 samatchi kuduro
#
# 1607704423037 samatchi anass
#
# 1607704424041 anass kuduro
#
# 1607704425045 anass kuduro
#
# 1607704426045 samatchi anass
#
# 1607704427046 kuduro anass
#
# 1607704428048 anass kuduro
#
# 1607704429048 samatchi anass
#
# 1607704430049 kuduro anass
#
# 1607704431053 anass kuduro
#
# 1607704432053 samatchi anass
#
# 1607704433055 samatchi anass
#
# 1607704434059 kuduro kuduro
#
# 1607704435061 samatchi samatchi
#
# 94

# %%
connected_hostnames("data/input_test_case_1.txt",1607880434801,1607880438820, 'Steeve')
# Out:
# Counter({'Hanny': 1, 'Hannibal': 2})

# %%
connected_hostnames("data/input-file.txt",1565647204351,1565733598341, 'Dristen')
# Out:
# Counter({'Aadison': 1,
#          'Wilkens': 1,
#          'Kahlina': 1,
#          'Alei': 1,
#          'Zhanasia': 1,
#          'Jamor': 1,
#          'Joy': 1})

# %%
connected_to("data/input_test_case_1.txt",1607880434801,1607880438820, 'Steeve')
# Out:
# Counter({'Hannibal': 1})

# %%
connected_to("data/input-file.txt",1565647204351,1565733598341, 'Jadon')
# Out:
# Counter({'Ahmya': 1,
#          'Kayleann': 1,
#          'Shainah': 1,
#          'Aniyah': 1,
#          'Eveleigh': 1,
#          'Caris': 1,
#          'Rahniya': 1,
#          'Remiel': 1})

# %%
received_from("data/input_test_case_1.txt",1607880434801,1607880438820, 'Steeve')
# Out:
# Counter({'Hannibal': 1, 'Hanny': 1})

# %%
received_from("data/input-file.txt",1565647204351,1565733598341, 'Dristen')
# Out:
# Counter({'Joy': 1,
#          'Jamor': 1,
#          'Zhanasia': 1,
#          'Alei': 1,
#          'Kahlina': 1,
#          'Wilkens': 1,
#          'Aadison': 1})

# %%
generated_conn("data/input_test_case_1.txt",1607880434801,1607880438820)
# Out:
# Counter({'Hannibal': 3, 'Steeve': 2, 'Hanny': 1})

# %%
most_generated_conn("data/input-file.txt",1565647204351,1565733598341).most_common(1)
# Out:
# [('Dristen', 7)]

# %%
if __name__ == '__main__':
    Thread(target = generate_log_files()).start()
    Thread(target = process_log_files()).start()

# %%
glob.glob("output/*.txt")
# Out:
# ['output/test_8.txt',
#  'output/test_9.txt',
#  'output/test_12.txt',
#  'output/test_10.txt',
#  'output/test_11.txt',
#  'output/test_2.txt',
#  'output/test_3.txt',
#  'output/test_1.txt',
#  'output/test_4.txt',
#  'output/test_5.txt',
#  'output/test_7.txt',
#  'output/test_6.txt']

# %%
sorted(glob.glob("output/*.txt"), key=os.path.getmtime)[::-1]
# Out:
# ['output/test_11.txt',
#  'output/test_12.txt',
#  'output/test_10.txt',
#  'output/test_9.txt',
#  'output/test_8.txt',
#  'output/test_7.txt',
#  'output/test_6.txt',
#  'output/test_5.txt',
#  'output/test_4.txt',
#  'output/test_3.txt',
#  'output/test_2.txt',
#  'output/test_1.txt']

# %%
import logging
import threading
import time

def thread_function(name):
    logging.info("Thread %s: starting", name)
    time.sleep(2)
    logging.info("Thread %s: finishing", name)

if __name__ == "__main__":
    format = "%(asctime)s: %(message)s"
    logging.basicConfig(format=format, level=logging.INFO,
                        datefmt="%H:%M:%S")

    logging.info("Main    : before creating thread")
    x = threading.Thread(target=thread_function, args=(1,), daemon=True)
    logging.info("Main    : before running thread")
    x.start()
    logging.info("Main    : wait for the thread to finish")
    # x.join()
    logging.info("Main    : all done")
# Out:
# 11:56:55: Main    : before creating thread
# 11:56:55: Main    : before running thread
# 11:56:55: Thread 1: starting
# 11:56:55: Main    : wait for the thread to finish
# 11:56:55: Main    : all done
# 11:56:57: Thread 1: finishing

# %%
import logging
import threading
import time

def thread_function(name):
    logging.info("Thread %s: starting", name)
    time.sleep(2)
    logging.info("Thread %s: finishing", name)

if __name__ == "__main__":
    format = "%(asctime)s: %(message)s"
    logging.basicConfig(format=format, level=logging.INFO,
                        datefmt="%H:%M:%S")

    threads = list()
    for index in range(3):
        logging.info("Main    : create and start thread %d.", index)
        x = threading.Thread(target=thread_function, args=(index,))
        threads.append(x)
        x.start()

    for index, thread in enumerate(threads):
        logging.info("Main    : before joining thread %d.", index)
        thread.join()
        logging.info("Main    : thread %d done", index)
# Out:
# 11:58:50: Main    : create and start thread 0.
# 11:58:50: Thread 0: starting
# 11:58:50: Main    : create and start thread 1.
# 11:58:50: Thread 1: starting
# 11:58:50: Main    : create and start thread 2.
# 11:58:50: Thread 2: starting
# 11:58:50: Main    : before joining thread 0.
# 11:58:52: Thread 0: finishing
# 11:58:52: Main    : thread 0 done
# 11:58:52: Main    : before joining thread 1.
# 11:58:52: Thread 1: finishing
# 11:58:52: Thread 2: finishing
# 11:58:52: Main    : thread 1 done
# 11:58:52: Main    : before joining thread 2.
# 11:58:52: Main    : thread 2 done

# %%
subjects = ['math', 'chemistry', 'biology', 'pyhsics']
grades = ['100', '83', '90', '92']

grades_dict = dict(zip(subjects, grades))
print(grades_dict)
# Out:
# {'math': '100', 'chemistry': '83', 'biology': '90', 'pyhsics': '92'}

# %%
[filename for filename in glob.glob("output/*.txt")]
# Out:
# ['output/log_101.txt',
#  'output/log_667.txt',
#  'output/log_673.txt',
#  'output/log_115.txt',
#  'output/log_129.txt',
#  'output/log_698.txt',
#  'output/log_465.txt',
#  'output/log_303.txt',
#  'output/log_317.txt',
#  'output/log_471.txt',
#  'output/log_459.txt',
#  'output/log_21.txt',
#  'output/log_35.txt',
#  'output/log_511.txt',
#  'output/log_277.txt',
#  'output/log_263.txt',
#  'output/log_505.txt',
#  'output/log_539.txt',
#  'output/log_288.txt',
#  'output/log_713.txt',
#  'output/log_707.txt',
#  'output/log_706.txt',
#  'output/log_712.txt',
#  'output/log_289.txt',
#  'output/log_538.txt',
#  'output/log_262.txt',
#  'output/log_504.txt',
#  'output/log_510.txt',
#  'output/log_276.txt',
#  'output/log_34.txt',
#  'output/log_20.txt',
#  'output/log_458.txt',
#  'output/log_316.txt',
#  'output/log_470.txt',
#  'output/log_464.txt',
#  'output/log_302.txt',
#  'output/log_699.txt',
#  'output/log_128.txt',
#  'output/log_672.txt',
#  'output/log_114.txt',
#  'output/log_100.txt',
#  'output/log_666.txt',
#  'output/log_116.txt',
#  'output/log_670.txt',
#  'output/log_664.txt',
#  'output/log_102.txt',
#  'output/log_658.txt',
#  'output/log_472.txt',
#  'output/log_314.txt',
#  'output/log_300.txt',
#  'output/log_466.txt',
#  'output/log_328.txt',
#  'output/log_36.txt',
#  'output/log_22.txt',
#  'output/log_499.txt',
#  'output/log_506.txt',
#  'output/log_260.txt',
#  'output/log_274.txt',
#  'output/log_512.txt',
#  'output/log_248.txt',
#  'output/log_704.txt',
#  'output/log_710.txt',
#  'output/log_711.txt',
#  'output/log_705.txt',
#  'output/log_249.txt',
#  'output/log_275.txt',
#  'output/log_513.txt',
#  'output/log_507.txt',
#  'output/log_261.txt',
#  'output/log_498.txt',
#  'output/log_23.txt',
#  'output/log_37.txt',
#  'output/log_329.txt',
#  'output/log_301.txt',
#  'output/log_467.txt',
#  'output/log_473.txt',
#  'output/log_315.txt',
#  'output/log_659.txt',
#  'output/log_665.txt',
#  'output/log_103.txt',
#  'output/log_117.txt',
#  'output/log_671.txt',
#  'output/log_649.txt',
#  'output/log_675.txt',
#  'output/log_113.txt',
#  'output/log_107.txt',
#  'output/log_661.txt',
#  'output/log_339.txt',
#  'output/log_311.txt',
#  'output/log_477.txt',
#  'output/log_463.txt',
#  'output/log_305.txt',
#  'output/log_488.txt',
#  'output/log_33.txt',
#  'output/log_27.txt',
#  'output/log_259.txt',
#  'output/log_265.txt',
#  'output/log_503.txt',
#  'output/log_517.txt',
#  'output/log_271.txt',
#  'output/log_701.txt',
#  'output/log_715.txt',
#  'output/log_714.txt',
#  'output/log_700.txt',
#  'output/log_516.txt',
#  'output/log_270.txt',
#  'output/log_264.txt',
#  'output/log_502.txt',
#  'output/log_258.txt',
#  'output/log_26.txt',
#  'output/log_32.txt',
#  'output/log_489.txt',
#  'output/log_462.txt',
#  'output/log_304.txt',
#  'output/log_310.txt',
#  'output/log_476.txt',
#  'output/log_338.txt',
#  'output/log_106.txt',
#  'output/log_660.txt',
#  'output/log_674.txt',
#  'output/log_112.txt',
#  'output/log_648.txt',
#  'output/log_138.txt',
#  'output/log_662.txt',
#  'output/log_104.txt',
#  'output/log_110.txt',
#  'output/log_676.txt',
#  'output/log_689.txt',
#  'output/log_448.txt',
#  'output/log_306.txt',
#  'output/log_460.txt',
#  'output/log_474.txt',
#  'output/log_312.txt',
#  'output/log_24.txt',
#  'output/log_30.txt',
#  'output/log_18.txt',
#  'output/log_528.txt',
#  'output/log_272.txt',
#  'output/log_514.txt',
#  'output/log_500.txt',
#  'output/log_266.txt',
#  'output/log_299.txt',
#  'output/log_716.txt',
#  'output/log_702.txt',
#  'output/log_703.txt',
#  'output/log_717.txt',
#  'output/log_298.txt',
#  'output/log_501.txt',
#  'output/log_267.txt',
#  'output/log_273.txt',
#  'output/log_515.txt',
#  'output/log_529.txt',
#  'output/log_19.txt',
#  'output/log_31.txt',
#  'output/log_25.txt',
#  'output/log_475.txt',
#  'output/log_313.txt',
#  'output/log_307.txt',
#  'output/log_461.txt',
#  'output/log_449.txt',
#  'output/log_688.txt',
#  'output/log_111.txt',
#  'output/log_677.txt',
#  'output/log_663.txt',
#  'output/log_105.txt',
#  'output/log_139.txt',
#  'output/log_604.txt',
#  'output/log_162.txt',
#  'output/log_176.txt',
#  'output/log_610.txt',
#  'output/log_638.txt',
#  'output/log_189.txt',
#  'output/log_360.txt',
#  'output/log_406.txt',
#  'output/log_412.txt',
#  'output/log_374.txt',
#  'output/log_81.txt',
#  'output/log_8.txt',
#  'output/log_95.txt',
#  'output/log_348.txt',
#  'output/log_42.txt',
#  'output/log_56.txt',
#  'output/log_214.txt',
#  'output/log_572.txt',
#  'output/log_566.txt',
#  'output/log_200.txt',
#  'output/log_228.txt',
#  'output/log_599.txt',
#  'output/log_598.txt',
#  'output/log_229.txt',
#  'output/log_567.txt',
#  'output/log_201.txt',
#  'output/log_215.txt',
#  'output/log_573.txt',
#  'output/log_57.txt',
#  'output/log_43.txt',
#  'output/log_94.txt',
#  'output/log_349.txt',
#  'output/log_9.txt',
#  'output/log_80.txt',
#  'output/log_413.txt',
#  'output/log_375.txt',
#  'output/log_361.txt',
#  'output/log_407.txt',
#  'output/log_188.txt',
#  'output/log_639.txt',
#  'output/log_177.txt',
#  'output/log_611.txt',
#  'output/log_605.txt',
#  'output/log_163.txt',
#  'output/log_613.txt',
#  'output/log_175.txt',
#  'output/log_161.txt',
#  'output/log_607.txt',
#  'output/log_149.txt',
#  'output/log_377.txt',
#  'output/log_411.txt',
#  'output/log_405.txt',
#  'output/log_363.txt',
#  'output/log_96.txt',
#  'output/log_82.txt',
#  'output/log_439.txt',
#  'output/log_69.txt',
#  'output/log_388.txt',
#  'output/log_55.txt',
#  'output/log_41.txt',
#  'output/log_203.txt',
#  'output/log_565.txt',
#  'output/log_571.txt',
#  'output/log_217.txt',
#  'output/log_559.txt',
#  'output/log_558.txt',
#  'output/log_570.txt',
#  'output/log_216.txt',
#  'output/log_202.txt',
#  'output/log_564.txt',
#  'output/log_40.txt',
#  'output/log_389.txt',
#  'output/log_54.txt',
#  'output/log_68.txt',
#  'output/log_438.txt',
#  'output/log_83.txt',
#  'output/log_97.txt',
#  'output/log_404.txt',
#  'output/log_362.txt',
#  'output/log_376.txt',
#  'output/log_410.txt',
#  'output/log_148.txt',
#  'output/log_160.txt',
#  'output/log_606.txt',
#  'output/log_612.txt',
#  'output/log_174.txt',
#  'output/log_158.txt',
#  'output/log_170.txt',
#  'output/log_616.txt',
#  'output/log_602.txt',
#  'output/log_164.txt',
#  'output/log_428.txt',
#  'output/log_93.txt',
#  'output/log_87.txt',
#  'output/log_414.txt',
#  'output/log_372.txt',
#  'output/log_366.txt',
#  'output/log_400.txt',
#  'output/log_50.txt',
#  'output/log_399.txt',
#  'output/log_44.txt',
#  'output/log_78.txt',
#  'output/log_548.txt',
#  'output/log_560.txt',
#  'output/log_206.txt',
#  'output/log_212.txt',
#  'output/log_574.txt',
#  'output/log_213.txt',
#  'output/log_575.txt',
#  'output/log_561.txt',
#  'output/log_207.txt',
#  'output/log_549.txt',
#  'output/log_79.txt',
#  'output/log_398.txt',
#  'output/log_45.txt',
#  'output/log_51.txt',
#  'output/log_367.txt',
#  'output/log_401.txt',
#  'output/log_415.txt',
#  'output/log_373.txt',
#  'output/log_86.txt',
#  'output/log_92.txt',
#  'output/log_429.txt',
#  'output/log_603.txt',
#  'output/log_165.txt',
#  'output/log_171.txt',
#  'output/log_617.txt',
#  'output/log_159.txt',
#  'output/log_629.txt',
#  'output/log_167.txt',
#  'output/log_601.txt',
#  'output/log_615.txt',
#  'output/log_173.txt',
#  'output/log_198.txt',
#  'output/log_84.txt',
#  'output/log_359.txt',
#  'output/log_90.txt',
#  'output/log_403.txt',
#  'output/log_365.txt',
#  'output/log_371.txt',
#  'output/log_417.txt',
#  'output/log_47.txt',
#  'output/log_53.txt',
#  'output/log_239.txt',
#  'output/log_577.txt',
#  'output/log_211.txt',
#  'output/log_205.txt',
#  'output/log_563.txt',
#  'output/log_588.txt',
#  'output/log_589.txt',
#  'output/log_204.txt',
#  'output/log_562.txt',
#  'output/log_576.txt',
#  'output/log_210.txt',
#  'output/log_238.txt',
#  'output/log_52.txt',
#  'output/log_46.txt',
#  'output/log_370.txt',
#  'output/log_416.txt',
#  'output/log_402.txt',
#  'output/log_364.txt',
#  'output/log_91.txt',
#  'output/log_85.txt',
#  'output/log_358.txt',
#  'output/log_199.txt',
#  'output/log_614.txt',
#  'output/log_172.txt',
#  'output/log_166.txt',
#  'output/log_600.txt',
#  'output/log_628.txt',
#  'output/log_625.txt',
#  'output/log_143.txt',
#  'output/log_157.txt',
#  'output/log_631.txt',
#  'output/log_619.txt',
#  'output/log_180.txt',
#  'output/log_194.txt',
#  'output/log_341.txt',
#  'output/log_427.txt',
#  'output/log_433.txt',
#  'output/log_1.txt',
#  'output/log_88.txt',
#  'output/log_355.txt',
#  'output/log_369.txt',
#  'output/log_382.txt',
#  'output/log_396.txt',
#  'output/log_63.txt',
#  'output/log_77.txt',
#  'output/log_235.txt',
#  'output/log_553.txt',
#  'output/log_547.txt',
#  'output/log_221.txt',
#  'output/log_209.txt',
#  'output/log_590.txt',
#  'output/log_584.txt',
#  'output/log_585.txt',
#  'output/log_591.txt',
#  'output/log_208.txt',
#  'output/log_546.txt',
#  'output/log_220.txt',
#  'output/log_234.txt',
#  'output/log_552.txt',
#  'output/log_76.txt',
#  'output/log_62.txt',
#  'output/log_397.txt',
#  'output/log_383.txt',
#  'output/log_368.txt',
#  'output/log_89.txt',
#  'output/log_432.txt',
#  'output/log_354.txt',
#  'output/log_340.txt',
#  'output/log_426.txt',
#  'output/log_195.txt',
#  'output/log_181.txt',
#  'output/log_618.txt',
#  'output/log_156.txt',
#  'output/log_630.txt',
#  'output/log_624.txt',
#  'output/log_142.txt',
#  'output/log_632.txt',
#  'output/log_154.txt',
#  'output/log_140.txt',
#  'output/log_626.txt',
#  'output/log_168.txt',
#  'output/log_197.txt',
#  'output/log_183.txt',
#  'output/log_356.txt',
#  'output/log_430.txt',
#  'output/log_2.txt',
#  'output/log_424.txt',
#  'output/log_342.txt',
#  'output/log_418.txt',
#  'output/log_395.txt',
#  'output/log_48.txt',
#  'output/log_381.txt',
#  'output/log_74.txt',
#  'output/log_60.txt',
#  'output/log_222.txt',
#  'output/log_544.txt',
#  'output/log_550.txt',
#  'output/log_236.txt',
#  'output/log_578.txt',
#  'output/log_587.txt',
#  'output/log_593.txt',
#  'output/log_592.txt',
#  'output/log_586.txt',
#  'output/log_579.txt',
#  'output/log_551.txt',
#  'output/log_237.txt',
#  'output/log_223.txt',
#  'output/log_545.txt',
#  'output/log_61.txt',
#  'output/log_75.txt',
#  'output/log_380.txt',
#  'output/log_394.txt',
#  'output/log_49.txt',
#  'output/log_419.txt',
#  'output/log_425.txt',
#  'output/log_343.txt',
#  'output/log_357.txt',
#  'output/log_3.txt',
#  'output/log_431.txt',
#  'output/log_182.txt',
#  'output/log_196.txt',
#  'output/log_169.txt',
#  'output/log_141.txt',
#  'output/log_627.txt',
#  'output/log_633.txt',
#  'output/log_155.txt',
#  'output/log_179.txt',
#  'output/log_151.txt',
#  'output/log_637.txt',
#  'output/log_623.txt',
#  'output/log_145.txt',
#  'output/log_192.txt',
#  'output/log_186.txt',
#  'output/log_409.txt',
#  'output/log_435.txt',
#  'output/log_7.txt',
#  'output/log_353.txt',
#  'output/log_347.txt',
#  'output/log_421.txt',
#  'output/log_71.txt',
#  'output/log_65.txt',
#  'output/log_390.txt',
#  'output/log_384.txt',
#  'output/log_59.txt',
#  'output/log_569.txt',
#  'output/log_541.txt',
#  'output/log_227.txt',
#  'output/log_233.txt',
#  'output/log_555.txt',
#  'output/log_582.txt',
#  'output/log_596.txt',
#  'output/log_597.txt',
#  'output/log_583.txt',
#  'output/log_232.txt',
#  'output/log_554.txt',
#  'output/log_540.txt',
#  'output/log_226.txt',
#  'output/log_568.txt',
#  'output/log_385.txt',
#  'output/log_58.txt',
#  'output/log_391.txt',
#  'output/log_64.txt',
#  'output/log_70.txt',
#  'output/log_346.txt',
#  'output/log_420.txt',
#  'output/log_6.txt',
#  'output/log_434.txt',
#  'output/log_352.txt',
#  'output/log_408.txt',
#  'output/log_187.txt',
#  'output/log_193.txt',
#  'output/log_622.txt',
#  'output/log_144.txt',
#  'output/log_150.txt',
#  'output/log_636.txt',
#  'output/log_178.txt',
#  'output/log_608.txt',
#  'output/log_146.txt',
#  'output/log_620.txt',
#  'output/log_634.txt',
#  'output/log_152.txt',
#  'output/log_185.txt',
#  'output/log_191.txt',
#  'output/log_378.txt',
#  'output/log_99.txt',
#  'output/log_422.txt',
#  'output/log_344.txt',
#  'output/log_350.txt',
#  'output/log_436.txt',
#  'output/log_4.txt',
#  'output/log_66.txt',
#  'output/log_72.txt',
#  'output/log_387.txt',
#  'output/log_393.txt',
#  'output/log_218.txt',
#  'output/log_556.txt',
#  'output/log_230.txt',
#  'output/log_224.txt',
#  'output/log_542.txt',
#  'output/log_595.txt',
#  'output/log_581.txt',
#  'output/log_580.txt',
#  'output/log_594.txt',
#  'output/log_225.txt',
#  'output/log_543.txt',
#  'output/log_557.txt',
#  'output/log_231.txt',
#  'output/log_219.txt',
#  'output/log_392.txt',
#  'output/log_386.txt',
#  'output/log_73.txt',
#  'output/log_67.txt',
#  'output/log_351.txt',
#  'output/log_5.txt',
#  'output/log_437.txt',
#  'output/log_423.txt',
#  'output/log_98.txt',
#  'output/log_345.txt',
#  'output/log_379.txt',
#  'output/log_190.txt',
#  'output/log_184.txt',
#  'output/log_635.txt',
#  'output/log_153.txt',
#  'output/log_147.txt',
#  'output/log_621.txt',
#  'output/log_609.txt',
#  'output/log_120.txt',
#  'output/log_646.txt',
#  'output/log_652.txt',
#  'output/log_134.txt',
#  'output/log_108.txt',
#  'output/log_685.txt',
#  'output/log_691.txt',
#  'output/log_444.txt',
#  'output/log_322.txt',
#  'output/log_336.txt',
#  'output/log_450.txt',
#  'output/log_478.txt',
#  'output/log_487.txt',
#  'output/log_493.txt',
#  'output/log_28.txt',
#  'output/log_14.txt',
#  'output/log_530.txt',
#  'output/log_256.txt',
#  'output/log_242.txt',
#  'output/log_524.txt',
#  'output/log_518.txt',
#  'output/log_295.txt',
#  'output/log_281.txt',
#  'output/log_280.txt',
#  'output/log_294.txt',
#  'output/log_519.txt',
#  'output/log_243.txt',
#  'output/log_525.txt',
#  'output/log_531.txt',
#  'output/log_257.txt',
#  'output/log_15.txt',
#  'output/log_29.txt',
#  'output/log_492.txt',
#  'output/log_486.txt',
#  'output/log_479.txt',
#  'output/log_337.txt',
#  'output/log_451.txt',
#  'output/log_445.txt',
#  'output/log_323.txt',
#  'output/log_690.txt',
#  'output/log_684.txt',
#  'output/log_109.txt',
#  'output/log_653.txt',
#  'output/log_135.txt',
#  'output/log_121.txt',
#  'output/log_647.txt',
#  'output/log_137.txt',
#  'output/log_651.txt',
#  'output/log_645.txt',
#  'output/log_123.txt',
#  'output/log_679.txt',
#  'output/log_692.txt',
#  'output/log_686.txt',
#  'output/log_453.txt',
#  'output/log_335.txt',
#  'output/log_321.txt',
#  'output/log_447.txt',
#  'output/log_309.txt',
#  'output/log_490.txt',
#  'output/log_484.txt',
#  'output/log_17.txt',
#  'output/log_527.txt',
#  'output/log_241.txt',
#  'output/log_255.txt',
#  'output/log_533.txt',
#  'output/log_269.txt',
#  'output/log_282.txt',
#  'output/log_296.txt',
#  'output/log_719.txt',
#  'output/log_718.txt',
#  'output/log_297.txt',
#  'output/log_283.txt',
#  'output/log_268.txt',
#  'output/log_254.txt',
#  'output/log_532.txt',
#  'output/log_526.txt',
#  'output/log_240.txt',
#  'output/log_16.txt',
#  'output/log_485.txt',
#  'output/log_491.txt',
#  'output/log_308.txt',
#  'output/log_320.txt',
#  'output/log_446.txt',
#  'output/log_452.txt',
#  'output/log_334.txt',
#  'output/log_687.txt',
#  'output/log_693.txt',
#  'output/log_678.txt',
#  'output/log_644.txt',
#  'output/log_122.txt',
#  'output/log_136.txt',
#  'output/log_650.txt',
#  'output/log_668.txt',
#  'output/log_654.txt',
#  'output/log_132.txt',
#  'output/log_126.txt',
#  'output/log_640.txt',
#  'output/log_697.txt',
#  'output/log_683.txt',
#  'output/log_318.txt',
#  'output/log_330.txt',
#  'output/log_456.txt',
#  'output/log_442.txt',
#  'output/log_324.txt',
#  'output/log_12.txt',
#  'output/log_495.txt',
#  'output/log_481.txt',
#  'output/log_278.txt',
#  'output/log_244.txt',
#  'output/log_522.txt',
#  'output/log_536.txt',
#  'output/log_250.txt',
#  'output/log_287.txt',
#  'output/log_293.txt',
#  'output/log_708.txt',
#  'output/log_709.txt',
#  'output/log_292.txt',
#  'output/log_286.txt',
#  'output/log_537.txt',
#  'output/log_251.txt',
#  'output/log_245.txt',
#  'output/log_523.txt',
#  'output/log_279.txt',
#  'output/log_480.txt',
#  'output/log_494.txt',
#  'output/log_13.txt',
#  'output/log_443.txt',
#  'output/log_325.txt',
#  'output/log_331.txt',
#  'output/log_457.txt',
#  'output/log_319.txt',
#  'output/log_682.txt',
#  'output/log_696.txt',
#  'output/log_127.txt',
#  'output/log_641.txt',
#  'output/log_655.txt',
#  'output/log_133.txt',
#  'output/log_669.txt',
#  'output/log_119.txt',
#  'output/log_643.txt',
#  'output/log_125.txt',
#  'output/log_131.txt',
#  'output/log_657.txt',
#  'output/log_680.txt',
#  'output/log_694.txt',
#  'output/log_469.txt',
#  'output/log_327.txt',
#  'output/log_441.txt',
#  'output/log_455.txt',
#  'output/log_333.txt',
#  'output/log_11.txt',
#  'output/log_39.txt',
#  'output/log_482.txt',
#  'output/log_496.txt',
#  'output/log_509.txt',
#  'output/log_253.txt',
#  'output/log_535.txt',
#  'output/log_521.txt',
#  'output/log_247.txt',
#  'output/log_290.txt',
#  'output/log_284.txt',
#  'output/log_285.txt',
#  'output/log_291.txt',
#  'output/log_520.txt',
#  'output/log_246.txt',
#  'output/log_252.txt',
#  'output/log_534.txt',
#  'output/log_508.txt',
#  'output/log_497.txt',
#  'output/log_483.txt',
#  'output/log_38.txt',
#  'output/log_10.txt',
#  'output/log_454.txt',
#  'output/log_332.txt',
#  'output/log_326.txt',
#  'output/log_440.txt',
#  'output/log_468.txt',
#  'output/log_695.txt',
#  'output/log_681.txt',
#  'output/log_130.txt',
#  'output/log_656.txt',
#  'output/log_642.txt',
#  'output/log_124.txt',
#  'output/log_118.txt']

# %%
https://www.geeksforgeeks.org/python-reversed-vs-1-which-one-is-faster/
https://www.csestack.org/difference-between-sort-sorted-python-list-performance/#:~:text=Sort%20vs%20Sorted%20Performance,-Which%20one%20is&text=Creating%20a%20list%20of%201000000%20integers%20selected%20randomly.&text=Here%2C%20sort()%20method%20is%20executing%20faster%20than%20sorted()%20function.&text=Here%2C%20sorted()%20function%20method,execution%20time%20in%20both%20cases.
https://www.geeksforgeeks.org/python-ways-to-flatten-a-2d-list/
